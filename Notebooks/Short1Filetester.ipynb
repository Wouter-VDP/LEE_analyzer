# %%
from __future__ import division
from __future__ import print_function
import numpy as np
import pandas as pd
from root_pandas import read_root

# %%
df = read_root("/home/wouter/Templates/July/bnb_nu_cosmic_0s0t_dev/10272555_98.root",'wouterNueCC/pandoratree')

# %%
for i in df.columns:
    print(i)
# Out:
# category
# n_tracks
# n_showers
# ccnc
# qsqr
# theta
# vx
# vy
# vz
# fiducial
# true_vx
# true_vy
# true_vz
# true_nu_fiducial
# true_shower_x_sce
# true_shower_y_sce
# true_shower_z_sce
# true_shower_pdg
# true_shower_depE
# true_vx_sce
# true_vy_sce
# true_vz_sce
# lepton_E
# lepton_theta
# nu_E
# passed
# numu_passed
# numu_cuts
# n_true_nu
# distance
# n_matched
# nu_matched_tracks
# nu_matched_showers
# nu_daughters_pdg
# nu_daughters_E
# nu_daughters_vx
# nu_daughters_vy
# nu_daughters_vz
# nu_daughters_endx
# nu_daughters_endy
# nu_daughters_endz
# nu_daughters_px
# nu_daughters_py
# nu_daughters_pz
# nu_track_ids
# nu_shower_ids
# nu_shower_daughters
# nu_track_daughters
# event
# run
# subrun
# bnbweight
# chosen_candidate
# candidate_pdg
# n_primaries
# primary_indexes
# number_tracks
# number_showers
# number_primary_tracks
# number_primary_showers
# flash_time
# flash_PE
# flash_y
# flash_z
# flash_sy
# flash_sz
# flash_matchid
# flash_x
# flash_score
# TPC_x
# ...

# %%
df[["flash_passed", "flash_PE_max", "fiducial", "passed","n_showers","candidate_pdg",'']]
# Out:
#                                  flash_passed  flash_PE_max    fiducial  \
# 0                                        [-2]   6089.513104  2147483648
# 1                            [-2, -2, -2, -2]     71.480661  2147483648
# 2                             [0, -2, -1, -2]   1791.821881           1
# 3                                [-4, -4, -4]      0.000000  2147483648
# 4                        [-4, -4, -4, -4, -4]      0.000000  2147483648
# 5                                 [-2, 0, -2]   1248.600431           1
# 6                                [-4, -4, -4]      0.000000  2147483648
# 7                                 [-2, 0, -1]    485.982540           0
# 8                    [-4, -4, -4, -4, -4, -4]      0.000000  2147483648
# 9                                [-2, -2, -2]   8905.270995  2147483648
# 10                           [-4, -4, -4, -4]      0.000000  2147483648
# 11                                   [-2, -2]     93.314681  2147483648
# ...

# %%
min(df[df["flash_PE_max"]>0]["flash_PE_max"])
# Out:
# 41.415905887910839

# %%
df.query('n_showers>1 & n_showers < 10')[['shower_pitch2','n_showers','shower_hits_w','shower_ncluster']]
# Out:
#                                          shower_pitch2  n_showers  \
# 46                    [0.538479941319, 0.360876858934]          2
# 63                     [5.07748928088, 0.385243955226]          2
# 67                     [1.20812518963, 0.492033727154]          2
# 90   [1.49355044317, 4.90488856899, 0.343290330752,...          4
# 94                    [0.370963896207, 0.931173416103]          2
# 113                      [4.08839552953, 1.4389427095]          2
# 133                              [0.306136915563, 0.0]          2
# 138                     [3.26583605488, 1.02336507627]          2
# 149                      [5.6477457736, 1.04492262851]          2
# 166  [0.476701539152, 0.343474217728, 0.44303212405...          4
# 176                    [0.636661984135, 1.29331249454]          2
# 201                     [1.50532893067, 1.00612932236]          2
# 207                    [1.21298690184, 0.421421072673]          2
# ...
